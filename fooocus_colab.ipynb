# %% [markdown]
# <a href="https://colab.research.google.com/github/yakovlev-1971/ton-labs-contracts/blob/master/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lllyasviel/stable-diffusion-webui-forge
# %cd stable-diffusion-webui-forge

# !pip install -q torch torchvision xformers
# !pip install -q -r requirements_versions.txt

# !python launch.py --share --xformers
# Out:
# Cloning into 'stable-diffusion-webui-forge'...
# remote: Enumerating objects: 41984, done.
# remote: Counting objects: 100% (13232/13232), done.
# remote: Compressing objects: 100% (6174/6174), done.
# remote: Total 41984 (delta 7095), reused 7058 (delta 7058), pack-reused 28752 (from 1)
# Receiving objects: 100% (41984/41984), 46.39 MiB | 17.54 MiB/s, done.
# Resolving deltas: 100% (29124/29124), done.
# /content/stable-diffusion-webui-forge/stable-diffusion-webui-forge
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.2 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.2 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# ...

# %%
# Фикс wandb (самое важное)
# !pip uninstall -y wandb protobuf
# !pip install wandb==0.16.6 protobuf==4.25.3 --force-reinstall
# Out:
# Found existing installation: wandb 0.26.1
# Uninstalling wandb-0.26.1:
#   Successfully uninstalled wandb-0.26.1
# Found existing installation: protobuf 3.20.0
# Uninstalling protobuf-3.20.0:
#   Successfully uninstalled protobuf-3.20.0
# ...
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 48.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.4/468.4 kB 38.3 MB/s eta 0:00:00
# ...
